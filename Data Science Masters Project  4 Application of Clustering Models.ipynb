# %% [markdown]
# # Project 4
# ## Project on Application of Clustering Models Sravanthi

# %% [markdown]
# Dataset Link
#
# https://drive.google.com/file/d/1pP0Rr83ri0voscgr95-YnVCBv6BYV22w/view
#
# Problem 1: There are various stocks for which we have collected a data set, which all stocks are apparently similar in performance
#
# Problem 2: How many Unique patterns that exist in the historical stock data set, based on fluctuations in price.
#
# Problem 3: Identify which all stocks are moving together and which all stocks are different from each other.
#
# Analyzing Dataset
#
# This looks like a regression problem as target variable (stock price) is a continuous variable.

# %%
# Core Libraries - Data manipulation and analysis
import pandas as pd
import numpy as np
import math
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns
from math import sqrt
from scipy.cluster.vq import kmeans,vq
from numpy import vstack,array

# Core Libraries - Machine Learning
import sklearn
 
# Importing Clustering - Modelling
from sklearn.cluster import KMeans


# Warnings Library - Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Download dataset from "https://drive.google.com/uc?id=1pP0Rr83ri0voscgr95-YnVCBv6BYV22w&export=download" and 
# place in the current folder
stock_data = pd.read_csv("data_stocks.csv")
stock_data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN    ...     NYSE.WYN  \
# 0    102.2300      85.2200       59.760       121.52    ...       84.370
# 1    102.1400      85.6500       59.840       121.48    ...       84.370
# 2    102.2125      85.5100       59.795       121.93    ...       84.585
# 3    102.1400      85.4872       59.620       121.44    ...       84.460
# 4    102.0600      85.7001       59.620       121.60    ...       84.470
#
#    NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# 0   119.035     44.40    39.88     82.03      7.36     50.22     63.86
# 1   119.035     44.11    39.88     82.03      7.38     50.22     63.74
# 2   119.260     44.09    39.98     82.02      7.36     50.12     63.75
# 3   119.260     44.25    39.99     82.02      7.35     50.16     63.88
# 4   119.610     44.11    39.96     82.03      7.36     50.20     63.91
#
#    NYSE.ZBH  NYSE.ZTS
# 0   122.000    53.350
# 1   121.770    53.350
# 2   121.700    53.365
# 3   121.700    53.380
# 4   121.695    53.240
#
# [5 rows x 502 columns]

# %% [markdown]
# #### Understanding the Dataset and Data

# %%
stock_data.shape
# Out:
# (41266, 502)

# %%
stock_data.columns
# Out:
# Index(['DATE', 'SP500', 'NASDAQ.AAL', 'NASDAQ.AAPL', 'NASDAQ.ADBE',
#        'NASDAQ.ADI', 'NASDAQ.ADP', 'NASDAQ.ADSK', 'NASDAQ.AKAM', 'NASDAQ.ALXN',
#        ...
#        'NYSE.WYN', 'NYSE.XEC', 'NYSE.XEL', 'NYSE.XL', 'NYSE.XOM', 'NYSE.XRX',
#        'NYSE.XYL', 'NYSE.YUM', 'NYSE.ZBH', 'NYSE.ZTS'],
#       dtype='object', length=502)

# %%
stock_data.tail()
# Out:
#              DATE    SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 41261  1504209360  2472.22       44.72       164.11      155.090       83.67
# 41262  1504209420  2471.77       44.73       164.12      155.160       83.65
# 41263  1504209480  2470.03       44.74       164.01      155.065       83.62
# 41264  1504209540  2471.49       44.71       163.88      154.960       83.58
# 41265  1504209600  2471.49       44.74       163.98      155.160       83.69
#
#        NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN    ...     NYSE.WYN  \
# 41261     106.565       114.49       47.150      142.425    ...       99.675
# 41262     106.590       114.52       47.150      142.450    ...       99.730
# 41263     106.520       114.47       47.150      142.330    ...       99.735
# 41264     106.400       114.33       47.135      142.170    ...       99.700
# 41265     106.470       114.46       47.150      142.410    ...       99.670
#
#        NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# 41261     99.53    49.485   40.955    76.360    32.285    62.110     76.88
# 41262     99.63    49.480   40.960    76.370    32.295    62.100     76.90
# 41263     99.64    49.495   40.940    76.315    32.290    62.090     76.88
# 41264     99.63    49.485   40.925    76.300    32.275    62.075     76.83
# 41265     99.64    49.490   40.940    76.320    32.270    62.070     76.81
#
#        NYSE.ZBH  NYSE.ZTS
# 41261    114.31   62.7250
# 41262    114.33   62.7100
# 41263    114.31   62.6850
# 41264    114.23   62.6301
# 41265    114.28   62.6800
#
# [5 rows x 502 columns]

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
stock_data.get_dtype_counts()
# Out:
# float64    501
# int64        1
# dtype: int64

# %% [markdown]
# ### Clean the data

# %% [markdown]
# Cleaning Null values

# %%
# Check if there are any null values. Since there are many columns, total sum of rows or elements which are null 
# across all columns tells us whether we need to consider to impute or remove those rows
stock_data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# No null values
# #### Cleaning zero values

# %%
stock_data.loc[(stock_data==0).any(axis=1),:].sum().sum()
# Out:
# 0.0

# %% [markdown]
# No zero values

# %% [markdown]
# #### Nonsensical values

# %%
stock_data.loc[(stock_data<0).any(axis=1),:].sum().sum()
# Out:
# 0.0

# %% [markdown]
# No negative values

# %% [markdown]
# ### Basic Statistical Information

# %%
stock_data.describe()
# Out:
#                DATE         SP500    NASDAQ.AAL   NASDAQ.AAPL  NASDAQ.ADBE  \
# count  4.126600e+04  41266.000000  41266.000000  41266.000000  41266.00000
# mean   1.497749e+09   2421.537882     47.708346    150.453566    141.31793
# std    3.822211e+06     39.557135      3.259377      6.236826      6.91674
# min    1.491226e+09   2329.139900     40.830000    140.160000    128.24000
# 25%    1.494432e+09   2390.860100     44.945400    144.640000    135.19500
# 50%    1.497638e+09   2430.149900     48.360000    149.945000    142.26000
# 75%    1.501090e+09   2448.820100     50.180000    155.065000    147.10000
# max    1.504210e+09   2490.649900     54.475000    164.510000    155.33000
#
#          NASDAQ.ADI    NASDAQ.ADP   NASDAQ.ADSK   NASDAQ.AKAM   NASDAQ.ALXN  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean      79.446873    103.480398    102.998608     50.894352    122.981163
# std        2.000283      4.424244      9.389788      4.833931     11.252010
# min       74.800000     95.870000     83.000000     44.650000     96.250000
# 25%       78.030000    101.300000     94.820000     47.440000    116.950000
# 50%       79.410000    102.440000    106.820000     49.509900    123.620000
# 75%       80.580000    104.660000    110.490000     52.230000    132.218800
# max       90.440000    121.770000    119.270000     62.560000    142.875000
#
#            ...           NYSE.WYN      NYSE.XEC      NYSE.XEL       NYSE.XL  \
# count      ...       41266.000000  41266.000000  41266.000000  41266.000000
# mean       ...          97.942211    104.740666     46.664402     43.043984
# std        ...           5.411795     10.606694      1.508444      1.714533
# min        ...          83.410000     89.510000     44.090000     39.120000
# 25%        ...          95.960000     95.010000     45.155000     41.955000
# 50%        ...          99.250000     99.660000     46.810000     43.200000
# 75%        ...         102.080000    117.034700     47.730000     44.370000
# max        ...         106.375000    123.870000     49.660000     47.210000
#
#            NYSE.XOM      NYSE.XRX      NYSE.XYL      NYSE.YUM      NYSE.ZBH  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean      80.784595     19.300718     54.541988     71.757891    121.423515
# std        1.840989     11.686532      3.526321      4.038272      5.607070
# min       76.060000      6.660000     48.820000     63.180000    110.120000
# 25%       80.220000      7.045000     51.630000     69.110000    117.580000
# 50%       81.150000     27.890000     53.850000     73.470000    120.650000
# 75%       82.062050     30.470000     57.140000     74.750000    126.000000
# max       83.630000     32.930000     62.130000     77.120000    133.450000
#
#            NYSE.ZTS
# count  41266.000000
# mean      60.183874
# std        3.346887
# min       52.300000
# 25%       59.620000
# 50%       61.585600
# 75%       62.540000
# max       63.840000
#
# [8 rows x 502 columns]

# %% [markdown]
# ### Non-Visual and Visual Analysis
# #### Uni-variate

# %%
stock_data.iloc[:,1:11].hist(bins=100, figsize=(20,20), layout=(5,2)) # Plotting the first 10 columns excluding the date
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D54B0A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D55B0CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D559CB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D5551DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D5579080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D557B2E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D55E2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D55F67B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D5609A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D5525C88>]],
#       dtype=object)

# %% [markdown]
# The distribution of values of stocks of the 10 companies, do not follow any specfic distribution,like normal distribution, multinomial distribution etc.
#
# #### Time Series plot for first 10 stock columns in the dataset by date
# Time Series Plot using Epoch time

# %%
# %matplotlib inline

# %%
plt.figure(figsize= (20,20))
for i,col in enumerate(stock_data.iloc[:,0:11].columns.values):
    if i==0:
        continue
    else:
        plt.figure(figsize= (30,5))
        plt.title(col + ' stock')
        plt.xlabel('Date')
        plt.ylabel('Stock value ' + str(col))
        plt.xticks(rotation=90)
        sns.lineplot(stock_data.iloc[:,0],stock_data.iloc[:,i])

# %% [markdown]
# Time Series Plot using Date Only

# %%
import datetime as dt

plt.figure(figsize= (20,20))
for i,col in enumerate(stock_data.iloc[:,0:10].columns.values):
    if i==0:
        continue
    else:
        plt.figure(figsize= (30,5))
        plt.title(col + ' stock')
        plt.xlabel('Date')
        plt.ylabel('Stock value ' + str(col))
        plt.xticks(rotation=90)
        sns.lineplot(stock_data.iloc[:,0].apply(lambda x:  dt.datetime.fromtimestamp(x).strftime('%Y-%m-%d')),
                     stock_data.iloc[:,i],)

# %%
import datetime as dt

date_df = pd.DataFrame()
date_df['date'] = stock_data.iloc[:,0].apply(lambda x:  dt.datetime.fromtimestamp(x).strftime('%Y-%m-%d'))
date_df['time'] = stock_data.iloc[:,0].apply(lambda x:  dt.datetime.fromtimestamp(x).strftime('%X'))
date_df.head()
# Out:
#          date      time
# 0  2017-04-03  14:30:00
# 1  2017-04-03  14:31:00
# 2  2017-04-03  14:32:00
# 3  2017-04-03  14:33:00
# 4  2017-04-03  14:34:00

# %%
date_df.groupby(by='date').count().shape # No. of days the data was taken
# Out:
# (106, 1)

# %%
stock_prices = stock_data.drop('DATE', axis =1)

# %% [markdown]
# In order to find out the optimal number of clusters upon which we can train our data, we need to find the least number of clusters where the change in Sum of Squared Errors (SSE) starts flatlining(becomes asymptotic) when we plot the SSE errors for different number of clusters according to the elbow method

# %%
# Calculate average annual percentage return and volatilities over the time period of the data in the dataset
performance = stock_prices.pct_change().mean() * 128
performance = pd.DataFrame(performance)
performance.columns = ['Performance']
performance['Volatility'] = stock_prices.pct_change().std() * sqrt(128)

#format the data as a numpy array to feed into the K-Means algorithm
data = np.asarray([np.asarray(performance['Performance']),np.asarray(performance['Volatility'])]).T

X = data
wc_sse = []
for k in range(2, 20):
    k_means = KMeans(n_clusters=k)
    k_means.fit(X)
    wc_sse.append(k_means.inertia_)

fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, 20), wc_sse)
plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %%
# computing K-Means with K = 6 (6 clusters)
centroids,_ = kmeans(data,6)
# assign each sample to a cluster
idx,_ = vq(data,centroids)

# some plotting using numpy's logical indexing
plt.plot(data[idx==0,0],data[idx==0,1],'ob',
     data[idx==1,0],data[idx==1,1],'oy',
     data[idx==2,0],data[idx==2,1],'or',
     data[idx==3,0],data[idx==3,1],'og',
     data[idx==4,0],data[idx==4,1],'om',
     data[idx==5,0],data[idx==5,1],'oc')

plt.plot(centroids[:,0],centroids[:,1],'sg',markersize=8)

# %%
#identify the outlier
print(performance.idxmax())
# Out:
# Performance    NYSE.XRX
# Volatility     NYSE.XRX
# dtype: object

# %%
#drop the relevant stock from our data
performance.drop('NYSE.XRX',inplace=True)

#recreate data to feed into the algorithm
data = np.asarray([np.asarray(performance['Performance']),np.asarray(performance['Volatility'])]).T

# %%
# computing K-Means with K = 6(6 clusters)
centroids,_ = kmeans(data,6)
# assign each sample to a cluster
idx,_ = vq(data,centroids)

# some plotting using numpy's logical indexing
plt.plot(data[idx==0,0],data[idx==0,1],'ob',
     data[idx==1,0],data[idx==1,1],'oy',
     data[idx==2,0],data[idx==2,1],'or',
     data[idx==3,0],data[idx==3,1],'og',
     data[idx==4,0],data[idx==4,1],'om',
     data[idx==5,0],data[idx==5,1],'oc')

plt.plot(centroids[:,0],centroids[:,1],'sg',markersize=8)

# %% [markdown]
# ### Problem 1: There are various stocks for which we have collected a data set, which all stocks are apparently similar in performance?

# %%
similar_performance = [(name,cluster) for name, cluster in zip(performance.index.values,idx)]
similar_performance
# Out:
# [('SP500', 5),
#  ('NASDAQ.AAL', 3),
#  ('NASDAQ.AAPL', 1),
#  ('NASDAQ.ADBE', 1),
#  ('NASDAQ.ADI', 3),
#  ('NASDAQ.ADP', 2),
#  ('NASDAQ.ADSK', 4),
#  ('NASDAQ.AKAM', 4),
#  ('NASDAQ.ALXN', 4),
#  ('NASDAQ.AMAT', 3),
#  ('NASDAQ.AMD', 0),
#  ('NASDAQ.AMGN', 1),
#  ('NASDAQ.AMZN', 2),
#  ('NASDAQ.ATVI', 3),
#  ('NASDAQ.AVGO', 3),
#  ('NASDAQ.BBBY', 4),
#  ('NASDAQ.BIIB', 2),
#  ('NASDAQ.CA', 3),
#  ('NASDAQ.CBOE', 1),
#  ('NASDAQ.CELG', 1),
#  ('NASDAQ.CERN', 1),
#  ('NASDAQ.CHRW', 2),
#  ('NASDAQ.CHTR', 3),
#  ('NASDAQ.CINF', 1),
#  ('NASDAQ.CMCSA', 1),
#  ('NASDAQ.CME', 1),
#  ('NASDAQ.COST', 2),
#  ('NASDAQ.CSCO', 2),
#  ('NASDAQ.CSX', 2),
#  ('NASDAQ.CTAS', 1),
#  ('NASDAQ.CTSH', 5),
#  ('NASDAQ.CTXS', 3),
#  ('NASDAQ.DISCA', 3),
#  ('NASDAQ.DISCK', 3),
#  ('NASDAQ.DISH', 3),
#  ('NASDAQ.DLTR', 4),
#  ('NASDAQ.EA', 3),
#  ('NASDAQ.EBAY', 2),
#  ('NASDAQ.EQIX', 2),
#  ('NASDAQ.ESRX', 3),
#  ('NASDAQ.ETFC', 3),
#  ('NASDAQ.EXPD', 1),
#  ('NASDAQ.EXPE', 2),
#  ('NASDAQ.FAST', 3),
#  ('NASDAQ.FB', 1),
#  ('NASDAQ.FFIV', 3),
#  ('NASDAQ.FISV', 5),
#  ('NASDAQ.FITB', 3),
#  ('NASDAQ.FLIR', 2),
#  ('NASDAQ.FOX', 3),
#  ('NASDAQ.FOXA', 3),
#  ('NASDAQ.GILD', 1),
#  ('NASDAQ.GOOG', 1),
#  ('NASDAQ.GOOGL', 1),
#  ('NASDAQ.GRMN', 2),
#  ('NASDAQ.GT', 4),
#  ('NASDAQ.HAS', 3),
#  ('NASDAQ.HBAN', 3),
#  ('NASDAQ.HOLX', 2),
#  ('NASDAQ.HSIC', 2),
#  ('NASDAQ.IDXX', 2),
#  ('NASDAQ.ILMN', 3),
#  ('NASDAQ.INCY', 0),
#  ('NASDAQ.INFO', 5),
#  ('NASDAQ.INTC', 1),
#  ('NASDAQ.INTU', 2),
#  ('NASDAQ.ISRG', 2),
#  ('NASDAQ.JBHT', 2),
#  ('NASDAQ.KHC', 5),
#  ('NASDAQ.KLAC', 3),
#  ('NASDAQ.LKQ', 2),
#  ('NASDAQ.LRCX', 3),
#  ('NASDAQ.MAR', 2),
#  ('NASDAQ.MAT', 4),
#  ('NASDAQ.MCHP', 2),
#  ('NASDAQ.MDLZ', 1),
#  ('NASDAQ.MNST', 1),
#  ('NASDAQ.MSFT', 5),
#  ('NASDAQ.MU', 4),
#  ('NASDAQ.MYL', 4),
#  ('NASDAQ.NAVI', 4),
#  ('NASDAQ.NDAQ', 5),
#  ('NASDAQ.NFLX', 4),
#  ('NASDAQ.NTAP', 3),
#  ('NASDAQ.NTRS', 2),
#  ('NASDAQ.NVDA', 0),
#  ('NASDAQ.NWS', 0),
#  ('NASDAQ.NWSA', 3),
#  ('NASDAQ.ORLY', 4),
#  ('NASDAQ.PAYX', 5),
#  ('NASDAQ.PBCT', 2),
#  ('NASDAQ.PCAR', 2),
#  ('NASDAQ.PCLN', 2),
#  ('NASDAQ.PDCO', 3),
#  ('NASDAQ.PYPL', 2),
#  ('NASDAQ.QCOM', 1),
#  ('NASDAQ.QRVO', 3),
#  ('NASDAQ.REGN', 4),
#  ('NASDAQ.ROST', 3),
#  ('NASDAQ.SBUX', 1),
#  ('NASDAQ.SNI', 4),
#  ('NASDAQ.SNPS', 1),
#  ('NASDAQ.SPLS', 4),
#  ('NASDAQ.SRCL', 2),
#  ('NASDAQ.STX', 0),
#  ('NASDAQ.SWKS', 3),
#  ('NASDAQ.SYMC', 3),
#  ('NASDAQ.TRIP', 4),
#  ('NASDAQ.TROW', 1),
#  ('NASDAQ.TSCO', 3),
#  ('NASDAQ.TXN', 1),
#  ('NASDAQ.ULTA', 4),
#  ('NASDAQ.VIAB', 4),
#  ('NASDAQ.VRSK', 1),
#  ('NASDAQ.VRSN', 1),
#  ('NASDAQ.VRTX', 0),
#  ('NASDAQ.WBA', 1),
#  ('NASDAQ.WDC', 4),
#  ('NASDAQ.WFM', 0),
#  ('NASDAQ.WLTW', 1),
#  ('NASDAQ.WYNN', 4),
#  ('NASDAQ.XLNX', 3),
#  ('NASDAQ.XRAY', 2),
#  ('NASDAQ.ZION', 3),
#  ('NYSE.A', 2),
#  ('NYSE.AAP', 0),
#  ('NYSE.ABBV', 5),
#  ('NYSE.ABC', 3),
#  ('NYSE.ABT', 5),
#  ('NYSE.ACN', 5),
#  ('NYSE.ADM', 2),
#  ('NYSE.ADS', 3),
#  ('NYSE.AEE', 5),
#  ('NYSE.AEP', 5),
#  ('NYSE.AES', 3),
#  ('NYSE.AET', 1),
#  ('NYSE.AFL', 5),
#  ('NYSE.AGN', 1),
#  ('NYSE.AIG', 5),
#  ('NYSE.AIV', 1),
#  ('NYSE.AIZ', 1),
#  ('NYSE.AJG', 1),
#  ('NYSE.ALB', 2),
#  ('NYSE.ALK', 3),
#  ('NYSE.ALL', 5),
#  ('NYSE.ALLE', 1),
#  ('NYSE.AME', 1),
#  ('NYSE.AMG', 3),
#  ('NYSE.AMP', 2),
#  ('NYSE.AMT', 1),
#  ('NYSE.AN', 4),
#  ('NYSE.ANTM', 2),
#  ('NYSE.AON', 5),
#  ('NYSE.APA', 4),
#  ('NYSE.APC', 4),
#  ('NYSE.APD', 5),
#  ('NYSE.APH', 5),
#  ('NYSE.ARE', 1),
#  ('NYSE.ARNC', 4),
#  ('NYSE.AVB', 1),
#  ('NYSE.AVY', 5),
#  ('NYSE.AWK', 5),
#  ('NYSE.AXP', 5),
#  ('NYSE.AYI', 4),
#  ('NYSE.AZO', 4),
#  ('NYSE.BA', 1),
#  ('NYSE.BAC', 3),
#  ('NYSE.BAX', 5),
#  ('NYSE.BBT', 1),
#  ('NYSE.BBY', 4),
#  ('NYSE.BCR', 4),
#  ('NYSE.BDX', 1),
#  ('NYSE.BEN', 1),
#  ('NYSE.BF.B', 3),
#  ('NYSE.BHI', 0),
#  ('NYSE.BK', 1),
#  ('NYSE.BLK', 1),
#  ('NYSE.BLL', 0),
#  ('NYSE.BMY', 1),
#  ('NYSE.BRK.B', 5),
#  ('NYSE.BSX', 1),
#  ('NYSE.BWA', 3),
#  ('NYSE.BXP', 1),
#  ('NYSE.C', 2),
#  ('NYSE.CAG', 1),
#  ('NYSE.CAH', 3),
#  ('NYSE.CAT', 2),
#  ('NYSE.CB', 5),
#  ('NYSE.CBG', 2),
#  ('NYSE.CBS', 2),
#  ('NYSE.CCI', 1),
#  ('NYSE.CCL', 1),
#  ('NYSE.CF', 4),
#  ('NYSE.CFG', 3),
#  ('NYSE.CHD', 5),
#  ('NYSE.CHK', 0),
#  ('NYSE.CI', 1),
#  ('NYSE.CL', 5),
#  ('NYSE.CLX', 5),
#  ('NYSE.CMA', 3),
#  ('NYSE.CMG', 3),
#  ('NYSE.CMI', 2),
#  ('NYSE.CMS', 5),
#  ('NYSE.CNC', 3),
#  ('NYSE.CNP', 5),
#  ('NYSE.COF', 2),
#  ('NYSE.COG', 3),
#  ('NYSE.COH', 4),
#  ('NYSE.COL', 2),
#  ('NYSE.COO', 2),
#  ('NYSE.COP', 2),
#  ('NYSE.COTY', 4),
#  ('NYSE.CPB', 2),
#  ('NYSE.CRM', 2),
#  ('NYSE.CSRA', 2),
#  ('NYSE.CTL', 3),
#  ('NYSE.CVS', 1),
#  ('NYSE.CVX', 5),
#  ('NYSE.CXO', 4),
#  ('NYSE.D', 5),
#  ('NYSE.DAL', 2),
#  ('NYSE.DD', 1),
#  ('NYSE.DE', 2),
#  ('NYSE.DFS', 2),
#  ('NYSE.DG', 3),
#  ('NYSE.DGX', 5),
#  ('NYSE.DHI', 2),
#  ('NYSE.DHR', 5),
#  ('NYSE.DIS', 1),
#  ('NYSE.DLPH', 3),
#  ('NYSE.DLR', 1),
#  ('NYSE.DOV', 2),
#  ('NYSE.DOW', 1),
#  ('NYSE.DPS', 1),
#  ('NYSE.DRI', 1),
#  ('NYSE.DTE', 5),
#  ('NYSE.DUK', 5),
#  ('NYSE.DVA', 2),
#  ('NYSE.DVN', 4),
#  ('NYSE.DXC', 2),
#  ('NYSE.ECL', 5),
#  ('NYSE.ED', 5),
#  ('NYSE.EFX', 1),
#  ('NYSE.EIX', 5),
#  ('NYSE.EL', 1),
#  ('NYSE.EMN', 1),
#  ('NYSE.EMR', 1),
#  ('NYSE.EOG', 2),
#  ('NYSE.EQR', 5),
#  ('NYSE.EQT', 4),
#  ('NYSE.ES', 5),
#  ('NYSE.ESS', 1),
#  ('NYSE.ETN', 1),
#  ('NYSE.ETR', 5),
#  ('NYSE.EVHC', 3),
#  ('NYSE.EW', 3),
#  ('NYSE.EXC', 5),
#  ('NYSE.EXR', 2),
#  ('NYSE.F', 2),
#  ('NYSE.FBHS', 1),
#  ('NYSE.FCX', 4),
#  ('NYSE.FDX', 1),
#  ('NYSE.FE', 1),
#  ('NYSE.FIS', 5),
#  ('NYSE.FL', 0),
#  ('NYSE.FLR', 3),
#  ('NYSE.FLS', 4),
#  ('NYSE.FMC', 3),
#  ('NYSE.FRT', 2),
#  ('NYSE.FTI', 4),
#  ('NYSE.FTV', 1),
#  ('NYSE.GD', 5),
#  ('NYSE.GE', 1),
#  ('NYSE.GGP', 3),
#  ('NYSE.GIS', 5),
#  ('NYSE.GLW', 1),
#  ('NYSE.GM', 2),
#  ('NYSE.GPC', 2),
#  ('NYSE.GPN', 1),
#  ('NYSE.GPS', 4),
#  ('NYSE.GS', 2),
#  ('NYSE.GWW', 4),
#  ('NYSE.HAL', 3),
#  ('NYSE.HBI', 3),
#  ('NYSE.HCA', 2),
#  ('NYSE.HCN', 1),
#  ('NYSE.HCP', 1),
#  ('NYSE.HD', 5),
#  ('NYSE.HES', 4),
#  ('NYSE.HIG', 5),
#  ('NYSE.HOG', 3),
#  ('NYSE.HON', 5),
#  ('NYSE.HP', 4),
#  ('NYSE.HPE', 2),
#  ('NYSE.HPQ', 2),
#  ('NYSE.HRB', 3),
#  ('NYSE.HRL', 2),
#  ('NYSE.HRS', 5),
#  ('NYSE.HST', 2),
#  ('NYSE.HSY', 5),
#  ('NYSE.HUM', 1),
#  ('NYSE.IBM', 5),
#  ('NYSE.ICE', 1),
#  ('NYSE.IFF', 1),
#  ('NYSE.IP', 1),
#  ('NYSE.IPG', 3),
#  ('NYSE.IR', 1),
#  ('NYSE.IRM', 1),
#  ('NYSE.IT', 1),
#  ('NYSE.ITW', 5),
#  ('NYSE.IVZ', 2),
#  ('NYSE.JCI', 2),
#  ('NYSE.JEC', 3),
#  ('NYSE.JNJ', 5),
#  ('NYSE.JNPR', 2),
#  ('NYSE.JPM', 1),
#  ('NYSE.JWN', 0),
#  ('NYSE.K', 5),
#  ('NYSE.KEY', 3),
#  ('NYSE.KIM', 3),
#  ('NYSE.KMB', 5),
#  ('NYSE.KMI', 2),
#  ('NYSE.KMX', 4),
#  ('NYSE.KO', 5),
#  ('NYSE.KORS', 0),
#  ('NYSE.KR', 4),
#  ('NYSE.KSS', 4),
#  ('NYSE.KSU', 2),
#  ('NYSE.L', 5),
#  ('NYSE.LB', 0),
#  ('NYSE.LEG', 1),
#  ('NYSE.LEN', 2),
#  ('NYSE.LH', 1),
#  ('NYSE.LLL', 1),
#  ('NYSE.LLY', 1),
#  ('NYSE.LMT', 5),
#  ('NYSE.LNC', 3),
#  ('NYSE.LNT', 5),
#  ('NYSE.LOW', 1),
#  ('NYSE.LUK', 1),
#  ('NYSE.LUV', 2),
#  ('NYSE.LVLT', 1),
#  ('NYSE.LYB', 2),
#  ('NYSE.M', 4),
#  ('NYSE.MA', 5),
#  ('NYSE.MAA', 1),
#  ('NYSE.MAC', 3),
#  ('NYSE.MAS', 1),
#  ('NYSE.MCD', 5),
#  ('NYSE.MCK', 3),
#  ('NYSE.MCO', 1),
#  ('NYSE.MDT', 5),
#  ('NYSE.MET', 3),
#  ('NYSE.MHK', 1),
#  ('NYSE.MKC', 1),
#  ('NYSE.MLM', 3),
#  ('NYSE.MMC', 5),
#  ('NYSE.MMM', 5),
#  ('NYSE.MNK', 4),
#  ('NYSE.MO', 1),
#  ('NYSE.MON', 5),
#  ('NYSE.MOS', 4),
#  ('NYSE.MPC', 2),
#  ('NYSE.MRK', 5),
#  ('NYSE.MRO', 0),
#  ('NYSE.MS', 3),
#  ('NYSE.MSI', 1),
#  ('NYSE.MTB', 2),
#  ('NYSE.MUR', 4),
#  ('NYSE.NBL', 3),
#  ('NYSE.NEE', 5),
#  ('NYSE.NEM', 3),
#  ('NYSE.NFX', 4),
#  ('NYSE.NI', 5),
#  ('NYSE.NKE', 2),
#  ('NYSE.NLSN', 2),
#  ('NYSE.NOC', 5),
#  ('NYSE.NOV', 3),
#  ('NYSE.NRG', 0),
#  ('NYSE.NSC', 1),
#  ('NYSE.NUE', 3),
#  ('NYSE.NWL', 3),
#  ('NYSE.O', 1),
#  ('NYSE.OKE', 2),
#  ('NYSE.OMC', 1),
#  ('NYSE.ORCL', 2),
#  ('NYSE.OXY', 2),
#  ('NYSE.PCG', 5),
#  ('NYSE.PEG', 5),
#  ('NYSE.PEP', 5),
#  ('NYSE.PFE', 5),
#  ('NYSE.PFG', 1),
#  ('NYSE.PG', 5),
#  ('NYSE.PGR', 5),
#  ('NYSE.PH', 1),
#  ('NYSE.PHM', 2),
#  ('NYSE.PKI', 1),
#  ('NYSE.PLD', 5),
#  ('NYSE.PM', 1),
#  ('NYSE.PNC', 2),
#  ('NYSE.PNR', 1),
#  ('NYSE.PNW', 5),
#  ('NYSE.PPG', 1),
#  ('NYSE.PPL', 5),
#  ('NYSE.PRGO', 4),
#  ('NYSE.PRU', 1),
#  ('NYSE.PSA', 2),
#  ('NYSE.PSX', 5),
#  ('NYSE.PVH', 3),
#  ('NYSE.PWR', 3),
#  ('NYSE.PX', 1),
#  ('NYSE.PXD', 4),
#  ('NYSE.RAI', 5),
#  ('NYSE.RCL', 3),
#  ('NYSE.REG', 2),
#  ('NYSE.RF', 4),
#  ('NYSE.RHI', 2),
#  ('NYSE.RHT', 3),
#  ('NYSE.RIG', 0),
#  ('NYSE.RJF', 2),
#  ('NYSE.RL', 4),
#  ('NYSE.ROK', 2),
#  ('NYSE.ROP', 1),
#  ('NYSE.RRC', 4),
#  ('NYSE.RSG', 5),
#  ('NYSE.RTN', 5),
#  ('NYSE.SCG', 1),
#  ('NYSE.SCHW', 2),
#  ('NYSE.SEE', 1),
#  ('NYSE.SHW', 1),
#  ('NYSE.SIG', 0),
#  ('NYSE.SJM', 1),
#  ('NYSE.SLB', 2),
#  ('NYSE.SLG', 1),
#  ('NYSE.SNA', 2),
#  ('NYSE.SO', 5),
#  ('NYSE.SPG', 2),
#  ('NYSE.SPGI', 1),
#  ('NYSE.SRE', 5),
#  ('NYSE.STI', 2),
#  ('NYSE.STT', 1),
#  ('NYSE.STZ', 2),
#  ('NYSE.SWK', 1),
#  ('NYSE.SYF', 0),
#  ('NYSE.SYK', 5),
#  ('NYSE.SYY', 1),
#  ('NYSE.T', 5),
#  ('NYSE.TAP', 2),
#  ('NYSE.TDG', 3),
#  ('NYSE.TEL', 1),
#  ('NYSE.TGT', 3),
#  ('NYSE.TIF', 3),
#  ('NYSE.TJX', 1),
#  ('NYSE.TMK', 5),
#  ('NYSE.TMO', 1),
#  ('NYSE.TRV', 5),
#  ('NYSE.TSN', 2),
#  ('NYSE.TSO', 2),
#  ('NYSE.TSS', 1),
#  ('NYSE.TWX', 5),
#  ('NYSE.TXT', 2),
#  ('NYSE.UA', 4),
#  ('NYSE.UAA', 4),
#  ('NYSE.UAL', 3),
#  ('NYSE.UDR', 1),
#  ('NYSE.UHS', 3),
#  ('NYSE.UNH', 5),
#  ('NYSE.UNM', 2),
#  ('NYSE.UNP', 1),
#  ('NYSE.UPS', 5),
#  ('NYSE.URI', 4),
#  ('NYSE.USB', 1),
#  ('NYSE.UTX', 5),
#  ('NYSE.V', 5),
#  ('NYSE.VAR', 1),
#  ('NYSE.VFC', 1),
#  ('NYSE.VLO', 2),
#  ('NYSE.VMC', 3),
#  ('NYSE.VNO', 4),
#  ('NYSE.VTR', 1),
#  ('NYSE.VZ', 1),
#  ('NYSE.WAT', 2),
#  ('NYSE.WEC', 5),
#  ('NYSE.WFC', 1),
#  ('NYSE.WHR', 3),
#  ('NYSE.WM', 5),
#  ('NYSE.WMB', 2),
#  ('NYSE.WMT', 1),
#  ('NYSE.WRK', 2),
#  ('NYSE.WU', 1),
#  ('NYSE.WY', 1),
#  ('NYSE.WYN', 1),
#  ('NYSE.XEC', 4),
#  ('NYSE.XEL', 5),
#  ('NYSE.XL', 1),
#  ('NYSE.XOM', 5),
#  ('NYSE.XYL', 1),
#  ('NYSE.YUM', 5),
#  ('NYSE.ZBH', 2),
#  ('NYSE.ZTS', 1)]

# %%
plt.figure(figsize = (20,200))
plt.title('Company Stocks Vs Clusters\n')
plt.ylim(-2,len(performance.index.values)+1)
plt.xlabel('Cluster Number')
plt.ylabel('Company Stocks')
plt.gca().invert_yaxis()
plt.grid(axis='both', alpha= 0.1)

sns.scatterplot(x=idx, y= performance.index.values, hue = idx,palette= 'Dark2', legend= False)

# %% [markdown]
# ## Problem 2: How many Unique patterns that exist in the historical stock data set, based on fluctuations in price?
#
# We can see that number of stocks cluster present are 6.
#
# ## Problem 3: Identify which all stocks are moving together and which all stocks are different from each other?

# %%
# stocks moving together

moving_together = [(name,cluster) for name, cluster in zip(performance.index.values,idx)]
moving_together
# Out:
# [('SP500', 5),
#  ('NASDAQ.AAL', 3),
#  ('NASDAQ.AAPL', 1),
#  ('NASDAQ.ADBE', 1),
#  ('NASDAQ.ADI', 3),
#  ('NASDAQ.ADP', 2),
#  ('NASDAQ.ADSK', 4),
#  ('NASDAQ.AKAM', 4),
#  ('NASDAQ.ALXN', 4),
#  ('NASDAQ.AMAT', 3),
#  ('NASDAQ.AMD', 0),
#  ('NASDAQ.AMGN', 1),
#  ('NASDAQ.AMZN', 2),
#  ('NASDAQ.ATVI', 3),
#  ('NASDAQ.AVGO', 3),
#  ('NASDAQ.BBBY', 4),
#  ('NASDAQ.BIIB', 2),
#  ('NASDAQ.CA', 3),
#  ('NASDAQ.CBOE', 1),
#  ('NASDAQ.CELG', 1),
#  ('NASDAQ.CERN', 1),
#  ('NASDAQ.CHRW', 2),
#  ('NASDAQ.CHTR', 3),
#  ('NASDAQ.CINF', 1),
#  ('NASDAQ.CMCSA', 1),
#  ('NASDAQ.CME', 1),
#  ('NASDAQ.COST', 2),
#  ('NASDAQ.CSCO', 2),
#  ('NASDAQ.CSX', 2),
#  ('NASDAQ.CTAS', 1),
#  ('NASDAQ.CTSH', 5),
#  ('NASDAQ.CTXS', 3),
#  ('NASDAQ.DISCA', 3),
#  ('NASDAQ.DISCK', 3),
#  ('NASDAQ.DISH', 3),
#  ('NASDAQ.DLTR', 4),
#  ('NASDAQ.EA', 3),
#  ('NASDAQ.EBAY', 2),
#  ('NASDAQ.EQIX', 2),
#  ('NASDAQ.ESRX', 3),
#  ('NASDAQ.ETFC', 3),
#  ('NASDAQ.EXPD', 1),
#  ('NASDAQ.EXPE', 2),
#  ('NASDAQ.FAST', 3),
#  ('NASDAQ.FB', 1),
#  ('NASDAQ.FFIV', 3),
#  ('NASDAQ.FISV', 5),
#  ('NASDAQ.FITB', 3),
#  ('NASDAQ.FLIR', 2),
#  ('NASDAQ.FOX', 3),
#  ('NASDAQ.FOXA', 3),
#  ('NASDAQ.GILD', 1),
#  ('NASDAQ.GOOG', 1),
#  ('NASDAQ.GOOGL', 1),
#  ('NASDAQ.GRMN', 2),
#  ('NASDAQ.GT', 4),
#  ('NASDAQ.HAS', 3),
#  ('NASDAQ.HBAN', 3),
#  ('NASDAQ.HOLX', 2),
#  ('NASDAQ.HSIC', 2),
#  ('NASDAQ.IDXX', 2),
#  ('NASDAQ.ILMN', 3),
#  ('NASDAQ.INCY', 0),
#  ('NASDAQ.INFO', 5),
#  ('NASDAQ.INTC', 1),
#  ('NASDAQ.INTU', 2),
#  ('NASDAQ.ISRG', 2),
#  ('NASDAQ.JBHT', 2),
#  ('NASDAQ.KHC', 5),
#  ('NASDAQ.KLAC', 3),
#  ('NASDAQ.LKQ', 2),
#  ('NASDAQ.LRCX', 3),
#  ('NASDAQ.MAR', 2),
#  ('NASDAQ.MAT', 4),
#  ('NASDAQ.MCHP', 2),
#  ('NASDAQ.MDLZ', 1),
#  ('NASDAQ.MNST', 1),
#  ('NASDAQ.MSFT', 5),
#  ('NASDAQ.MU', 4),
#  ('NASDAQ.MYL', 4),
#  ('NASDAQ.NAVI', 4),
#  ('NASDAQ.NDAQ', 5),
#  ('NASDAQ.NFLX', 4),
#  ('NASDAQ.NTAP', 3),
#  ('NASDAQ.NTRS', 2),
#  ('NASDAQ.NVDA', 0),
#  ('NASDAQ.NWS', 0),
#  ('NASDAQ.NWSA', 3),
#  ('NASDAQ.ORLY', 4),
#  ('NASDAQ.PAYX', 5),
#  ('NASDAQ.PBCT', 2),
#  ('NASDAQ.PCAR', 2),
#  ('NASDAQ.PCLN', 2),
#  ('NASDAQ.PDCO', 3),
#  ('NASDAQ.PYPL', 2),
#  ('NASDAQ.QCOM', 1),
#  ('NASDAQ.QRVO', 3),
#  ('NASDAQ.REGN', 4),
#  ('NASDAQ.ROST', 3),
#  ('NASDAQ.SBUX', 1),
#  ('NASDAQ.SNI', 4),
#  ('NASDAQ.SNPS', 1),
#  ('NASDAQ.SPLS', 4),
#  ('NASDAQ.SRCL', 2),
#  ('NASDAQ.STX', 0),
#  ('NASDAQ.SWKS', 3),
#  ('NASDAQ.SYMC', 3),
#  ('NASDAQ.TRIP', 4),
#  ('NASDAQ.TROW', 1),
#  ('NASDAQ.TSCO', 3),
#  ('NASDAQ.TXN', 1),
#  ('NASDAQ.ULTA', 4),
#  ('NASDAQ.VIAB', 4),
#  ('NASDAQ.VRSK', 1),
#  ('NASDAQ.VRSN', 1),
#  ('NASDAQ.VRTX', 0),
#  ('NASDAQ.WBA', 1),
#  ('NASDAQ.WDC', 4),
#  ('NASDAQ.WFM', 0),
#  ('NASDAQ.WLTW', 1),
#  ('NASDAQ.WYNN', 4),
#  ('NASDAQ.XLNX', 3),
#  ('NASDAQ.XRAY', 2),
#  ('NASDAQ.ZION', 3),
#  ('NYSE.A', 2),
#  ('NYSE.AAP', 0),
#  ('NYSE.ABBV', 5),
#  ('NYSE.ABC', 3),
#  ('NYSE.ABT', 5),
#  ('NYSE.ACN', 5),
#  ('NYSE.ADM', 2),
#  ('NYSE.ADS', 3),
#  ('NYSE.AEE', 5),
#  ('NYSE.AEP', 5),
#  ('NYSE.AES', 3),
#  ('NYSE.AET', 1),
#  ('NYSE.AFL', 5),
#  ('NYSE.AGN', 1),
#  ('NYSE.AIG', 5),
#  ('NYSE.AIV', 1),
#  ('NYSE.AIZ', 1),
#  ('NYSE.AJG', 1),
#  ('NYSE.ALB', 2),
#  ('NYSE.ALK', 3),
#  ('NYSE.ALL', 5),
#  ('NYSE.ALLE', 1),
#  ('NYSE.AME', 1),
#  ('NYSE.AMG', 3),
#  ('NYSE.AMP', 2),
#  ('NYSE.AMT', 1),
#  ('NYSE.AN', 4),
#  ('NYSE.ANTM', 2),
#  ('NYSE.AON', 5),
#  ('NYSE.APA', 4),
#  ('NYSE.APC', 4),
#  ('NYSE.APD', 5),
#  ('NYSE.APH', 5),
#  ('NYSE.ARE', 1),
#  ('NYSE.ARNC', 4),
#  ('NYSE.AVB', 1),
#  ('NYSE.AVY', 5),
#  ('NYSE.AWK', 5),
#  ('NYSE.AXP', 5),
#  ('NYSE.AYI', 4),
#  ('NYSE.AZO', 4),
#  ('NYSE.BA', 1),
#  ('NYSE.BAC', 3),
#  ('NYSE.BAX', 5),
#  ('NYSE.BBT', 1),
#  ('NYSE.BBY', 4),
#  ('NYSE.BCR', 4),
#  ('NYSE.BDX', 1),
#  ('NYSE.BEN', 1),
#  ('NYSE.BF.B', 3),
#  ('NYSE.BHI', 0),
#  ('NYSE.BK', 1),
#  ('NYSE.BLK', 1),
#  ('NYSE.BLL', 0),
#  ('NYSE.BMY', 1),
#  ('NYSE.BRK.B', 5),
#  ('NYSE.BSX', 1),
#  ('NYSE.BWA', 3),
#  ('NYSE.BXP', 1),
#  ('NYSE.C', 2),
#  ('NYSE.CAG', 1),
#  ('NYSE.CAH', 3),
#  ('NYSE.CAT', 2),
#  ('NYSE.CB', 5),
#  ('NYSE.CBG', 2),
#  ('NYSE.CBS', 2),
#  ('NYSE.CCI', 1),
#  ('NYSE.CCL', 1),
#  ('NYSE.CF', 4),
#  ('NYSE.CFG', 3),
#  ('NYSE.CHD', 5),
#  ('NYSE.CHK', 0),
#  ('NYSE.CI', 1),
#  ('NYSE.CL', 5),
#  ('NYSE.CLX', 5),
#  ('NYSE.CMA', 3),
#  ('NYSE.CMG', 3),
#  ('NYSE.CMI', 2),
#  ('NYSE.CMS', 5),
#  ('NYSE.CNC', 3),
#  ('NYSE.CNP', 5),
#  ('NYSE.COF', 2),
#  ('NYSE.COG', 3),
#  ('NYSE.COH', 4),
#  ('NYSE.COL', 2),
#  ('NYSE.COO', 2),
#  ('NYSE.COP', 2),
#  ('NYSE.COTY', 4),
#  ('NYSE.CPB', 2),
#  ('NYSE.CRM', 2),
#  ('NYSE.CSRA', 2),
#  ('NYSE.CTL', 3),
#  ('NYSE.CVS', 1),
#  ('NYSE.CVX', 5),
#  ('NYSE.CXO', 4),
#  ('NYSE.D', 5),
#  ('NYSE.DAL', 2),
#  ('NYSE.DD', 1),
#  ('NYSE.DE', 2),
#  ('NYSE.DFS', 2),
#  ('NYSE.DG', 3),
#  ('NYSE.DGX', 5),
#  ('NYSE.DHI', 2),
#  ('NYSE.DHR', 5),
#  ('NYSE.DIS', 1),
#  ('NYSE.DLPH', 3),
#  ('NYSE.DLR', 1),
#  ('NYSE.DOV', 2),
#  ('NYSE.DOW', 1),
#  ('NYSE.DPS', 1),
#  ('NYSE.DRI', 1),
#  ('NYSE.DTE', 5),
#  ('NYSE.DUK', 5),
#  ('NYSE.DVA', 2),
#  ('NYSE.DVN', 4),
#  ('NYSE.DXC', 2),
#  ('NYSE.ECL', 5),
#  ('NYSE.ED', 5),
#  ('NYSE.EFX', 1),
#  ('NYSE.EIX', 5),
#  ('NYSE.EL', 1),
#  ('NYSE.EMN', 1),
#  ('NYSE.EMR', 1),
#  ('NYSE.EOG', 2),
#  ('NYSE.EQR', 5),
#  ('NYSE.EQT', 4),
#  ('NYSE.ES', 5),
#  ('NYSE.ESS', 1),
#  ('NYSE.ETN', 1),
#  ('NYSE.ETR', 5),
#  ('NYSE.EVHC', 3),
#  ('NYSE.EW', 3),
#  ('NYSE.EXC', 5),
#  ('NYSE.EXR', 2),
#  ('NYSE.F', 2),
#  ('NYSE.FBHS', 1),
#  ('NYSE.FCX', 4),
#  ('NYSE.FDX', 1),
#  ('NYSE.FE', 1),
#  ('NYSE.FIS', 5),
#  ('NYSE.FL', 0),
#  ('NYSE.FLR', 3),
#  ('NYSE.FLS', 4),
#  ('NYSE.FMC', 3),
#  ('NYSE.FRT', 2),
#  ('NYSE.FTI', 4),
#  ('NYSE.FTV', 1),
#  ('NYSE.GD', 5),
#  ('NYSE.GE', 1),
#  ('NYSE.GGP', 3),
#  ('NYSE.GIS', 5),
#  ('NYSE.GLW', 1),
#  ('NYSE.GM', 2),
#  ('NYSE.GPC', 2),
#  ('NYSE.GPN', 1),
#  ('NYSE.GPS', 4),
#  ('NYSE.GS', 2),
#  ('NYSE.GWW', 4),
#  ('NYSE.HAL', 3),
#  ('NYSE.HBI', 3),
#  ('NYSE.HCA', 2),
#  ('NYSE.HCN', 1),
#  ('NYSE.HCP', 1),
#  ('NYSE.HD', 5),
#  ('NYSE.HES', 4),
#  ('NYSE.HIG', 5),
#  ('NYSE.HOG', 3),
#  ('NYSE.HON', 5),
#  ('NYSE.HP', 4),
#  ('NYSE.HPE', 2),
#  ('NYSE.HPQ', 2),
#  ('NYSE.HRB', 3),
#  ('NYSE.HRL', 2),
#  ('NYSE.HRS', 5),
#  ('NYSE.HST', 2),
#  ('NYSE.HSY', 5),
#  ('NYSE.HUM', 1),
#  ('NYSE.IBM', 5),
#  ('NYSE.ICE', 1),
#  ('NYSE.IFF', 1),
#  ('NYSE.IP', 1),
#  ('NYSE.IPG', 3),
#  ('NYSE.IR', 1),
#  ('NYSE.IRM', 1),
#  ('NYSE.IT', 1),
#  ('NYSE.ITW', 5),
#  ('NYSE.IVZ', 2),
#  ('NYSE.JCI', 2),
#  ('NYSE.JEC', 3),
#  ('NYSE.JNJ', 5),
#  ('NYSE.JNPR', 2),
#  ('NYSE.JPM', 1),
#  ('NYSE.JWN', 0),
#  ('NYSE.K', 5),
#  ('NYSE.KEY', 3),
#  ('NYSE.KIM', 3),
#  ('NYSE.KMB', 5),
#  ('NYSE.KMI', 2),
#  ('NYSE.KMX', 4),
#  ('NYSE.KO', 5),
#  ('NYSE.KORS', 0),
#  ('NYSE.KR', 4),
#  ('NYSE.KSS', 4),
#  ('NYSE.KSU', 2),
#  ('NYSE.L', 5),
#  ('NYSE.LB', 0),
#  ('NYSE.LEG', 1),
#  ('NYSE.LEN', 2),
#  ('NYSE.LH', 1),
#  ('NYSE.LLL', 1),
#  ('NYSE.LLY', 1),
#  ('NYSE.LMT', 5),
#  ('NYSE.LNC', 3),
#  ('NYSE.LNT', 5),
#  ('NYSE.LOW', 1),
#  ('NYSE.LUK', 1),
#  ('NYSE.LUV', 2),
#  ('NYSE.LVLT', 1),
#  ('NYSE.LYB', 2),
#  ('NYSE.M', 4),
#  ('NYSE.MA', 5),
#  ('NYSE.MAA', 1),
#  ('NYSE.MAC', 3),
#  ('NYSE.MAS', 1),
#  ('NYSE.MCD', 5),
#  ('NYSE.MCK', 3),
#  ('NYSE.MCO', 1),
#  ('NYSE.MDT', 5),
#  ('NYSE.MET', 3),
#  ('NYSE.MHK', 1),
#  ('NYSE.MKC', 1),
#  ('NYSE.MLM', 3),
#  ('NYSE.MMC', 5),
#  ('NYSE.MMM', 5),
#  ('NYSE.MNK', 4),
#  ('NYSE.MO', 1),
#  ('NYSE.MON', 5),
#  ('NYSE.MOS', 4),
#  ('NYSE.MPC', 2),
#  ('NYSE.MRK', 5),
#  ('NYSE.MRO', 0),
#  ('NYSE.MS', 3),
#  ('NYSE.MSI', 1),
#  ('NYSE.MTB', 2),
#  ('NYSE.MUR', 4),
#  ('NYSE.NBL', 3),
#  ('NYSE.NEE', 5),
#  ('NYSE.NEM', 3),
#  ('NYSE.NFX', 4),
#  ('NYSE.NI', 5),
#  ('NYSE.NKE', 2),
#  ('NYSE.NLSN', 2),
#  ('NYSE.NOC', 5),
#  ('NYSE.NOV', 3),
#  ('NYSE.NRG', 0),
#  ('NYSE.NSC', 1),
#  ('NYSE.NUE', 3),
#  ('NYSE.NWL', 3),
#  ('NYSE.O', 1),
#  ('NYSE.OKE', 2),
#  ('NYSE.OMC', 1),
#  ('NYSE.ORCL', 2),
#  ('NYSE.OXY', 2),
#  ('NYSE.PCG', 5),
#  ('NYSE.PEG', 5),
#  ('NYSE.PEP', 5),
#  ('NYSE.PFE', 5),
#  ('NYSE.PFG', 1),
#  ('NYSE.PG', 5),
#  ('NYSE.PGR', 5),
#  ('NYSE.PH', 1),
#  ('NYSE.PHM', 2),
#  ('NYSE.PKI', 1),
#  ('NYSE.PLD', 5),
#  ('NYSE.PM', 1),
#  ('NYSE.PNC', 2),
#  ('NYSE.PNR', 1),
#  ('NYSE.PNW', 5),
#  ('NYSE.PPG', 1),
#  ('NYSE.PPL', 5),
#  ('NYSE.PRGO', 4),
#  ('NYSE.PRU', 1),
#  ('NYSE.PSA', 2),
#  ('NYSE.PSX', 5),
#  ('NYSE.PVH', 3),
#  ('NYSE.PWR', 3),
#  ('NYSE.PX', 1),
#  ('NYSE.PXD', 4),
#  ('NYSE.RAI', 5),
#  ('NYSE.RCL', 3),
#  ('NYSE.REG', 2),
#  ('NYSE.RF', 4),
#  ('NYSE.RHI', 2),
#  ('NYSE.RHT', 3),
#  ('NYSE.RIG', 0),
#  ('NYSE.RJF', 2),
#  ('NYSE.RL', 4),
#  ('NYSE.ROK', 2),
#  ('NYSE.ROP', 1),
#  ('NYSE.RRC', 4),
#  ('NYSE.RSG', 5),
#  ('NYSE.RTN', 5),
#  ('NYSE.SCG', 1),
#  ('NYSE.SCHW', 2),
#  ('NYSE.SEE', 1),
#  ('NYSE.SHW', 1),
#  ('NYSE.SIG', 0),
#  ('NYSE.SJM', 1),
#  ('NYSE.SLB', 2),
#  ('NYSE.SLG', 1),
#  ('NYSE.SNA', 2),
#  ('NYSE.SO', 5),
#  ('NYSE.SPG', 2),
#  ('NYSE.SPGI', 1),
#  ('NYSE.SRE', 5),
#  ('NYSE.STI', 2),
#  ('NYSE.STT', 1),
#  ('NYSE.STZ', 2),
#  ('NYSE.SWK', 1),
#  ('NYSE.SYF', 0),
#  ('NYSE.SYK', 5),
#  ('NYSE.SYY', 1),
#  ('NYSE.T', 5),
#  ('NYSE.TAP', 2),
#  ('NYSE.TDG', 3),
#  ('NYSE.TEL', 1),
#  ('NYSE.TGT', 3),
#  ('NYSE.TIF', 3),
#  ('NYSE.TJX', 1),
#  ('NYSE.TMK', 5),
#  ('NYSE.TMO', 1),
#  ('NYSE.TRV', 5),
#  ('NYSE.TSN', 2),
#  ('NYSE.TSO', 2),
#  ('NYSE.TSS', 1),
#  ('NYSE.TWX', 5),
#  ('NYSE.TXT', 2),
#  ('NYSE.UA', 4),
#  ('NYSE.UAA', 4),
#  ('NYSE.UAL', 3),
#  ('NYSE.UDR', 1),
#  ('NYSE.UHS', 3),
#  ('NYSE.UNH', 5),
#  ('NYSE.UNM', 2),
#  ('NYSE.UNP', 1),
#  ('NYSE.UPS', 5),
#  ('NYSE.URI', 4),
#  ('NYSE.USB', 1),
#  ('NYSE.UTX', 5),
#  ('NYSE.V', 5),
#  ('NYSE.VAR', 1),
#  ('NYSE.VFC', 1),
#  ('NYSE.VLO', 2),
#  ('NYSE.VMC', 3),
#  ('NYSE.VNO', 4),
#  ('NYSE.VTR', 1),
#  ('NYSE.VZ', 1),
#  ('NYSE.WAT', 2),
#  ('NYSE.WEC', 5),
#  ('NYSE.WFC', 1),
#  ('NYSE.WHR', 3),
#  ('NYSE.WM', 5),
#  ('NYSE.WMB', 2),
#  ('NYSE.WMT', 1),
#  ('NYSE.WRK', 2),
#  ('NYSE.WU', 1),
#  ('NYSE.WY', 1),
#  ('NYSE.WYN', 1),
#  ('NYSE.XEC', 4),
#  ('NYSE.XEL', 5),
#  ('NYSE.XL', 1),
#  ('NYSE.XOM', 5),
#  ('NYSE.XYL', 1),
#  ('NYSE.YUM', 5),
#  ('NYSE.ZBH', 2),
#  ('NYSE.ZTS', 1)]
